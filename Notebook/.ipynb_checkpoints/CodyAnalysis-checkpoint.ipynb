# %% [markdown]
# # Does the number of votes a movie recieves impact the movie's rating?

# %%
import pandas as pd

import matplotlib.pyplot as plt

import scipy.stats as st

# %%
file = ("../Resources/final_df.csv")

# %%
#Read in csv
final_df = pd.read_csv(file)
final_df
# Out:
#         Unnamed: 0     tconst                    primaryTitle  startYear  \
# 0                9  tt0000009                      Miss Jerry       1894
# 1              412  tt0000574     The Story of the Kelly Gang       1906
# 2              481  tt0000679  The Fairylogue and Radio-Plays       1908
# 3              781  tt0001184         Don Juan de Serrallonga       1910
# 4              813  tt0001258           The White Slave Trade       1910
# ...            ...        ...                             ...        ...
# 100250      474785  tt0953564              A Footstep on Sand       1988
# 100251      474790  tt0953605                          Sukran       2005
# 100252      474798  tt0953659            A Suitcaseful of Sex       1971
# 100253      474868  tt0953903                       Year 1863       1922
# 100254      474869  tt0953904                  Romeo i Julcia       1933
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 0                   45                 Romance            5.3        89
# 1                   70   Biography,Crime,Drama            6.1       562
# 2                  120       Adventure,Fantasy            4.8        34
# 3                   58         Adventure,Drama            3.1        11
# 4                   45                   Drama            5.7        79
# ...                ...                     ...            ...       ...
# 100250             101  Drama,History,Thriller            6.6        11
# 100251             165            Action,Drama            3.2       442
# 100252              93                  Comedy            5.4        22
# 100253              93   Drama,History,Romance            6.4        15
# 100254              71                  Comedy            6.1        11
#
# [100255 rows x 8 columns]

# %%
#Remove unnecessary column
final_df = final_df.drop(columns = "Unnamed: 0")
final_df
# Out:
#            tconst                    primaryTitle  startYear  runtimeMinutes  \
# 0       tt0000009                      Miss Jerry       1894              45
# 1       tt0000574     The Story of the Kelly Gang       1906              70
# 2       tt0000679  The Fairylogue and Radio-Plays       1908             120
# 3       tt0001184         Don Juan de Serrallonga       1910              58
# 4       tt0001258           The White Slave Trade       1910              45
# ...           ...                             ...        ...             ...
# 100250  tt0953564              A Footstep on Sand       1988             101
# 100251  tt0953605                          Sukran       2005             165
# 100252  tt0953659            A Suitcaseful of Sex       1971              93
# 100253  tt0953903                       Year 1863       1922              93
# 100254  tt0953904                  Romeo i Julcia       1933              71
#
#                         genres  averageRating  numVotes
# 0                      Romance            5.3        89
# 1        Biography,Crime,Drama            6.1       562
# 2            Adventure,Fantasy            4.8        34
# 3              Adventure,Drama            3.1        11
# 4                        Drama            5.7        79
# ...                        ...            ...       ...
# 100250  Drama,History,Thriller            6.6        11
# 100251            Action,Drama            3.2       442
# 100252                  Comedy            5.4        22
# 100253   Drama,History,Romance            6.4        15
# 100254                  Comedy            6.1        11
#
# [100255 rows x 7 columns]

# %%
#Set x and y values for entire dataset
x_values = final_df['numVotes']
y_values = final_df['averageRating']

# %%
#Plot a scatterplot for entire dataset
plt.title("Number of Votes vs Average Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(x_values, y_values, marker = "o", color = "green")
plt.show()

# %%
print(f"The correlation coefficient between Number of Votes and Rating is {round(st.pearsonr(x_values,y_values)[0],2)}")
# Out:
# The correlation coefficient between Number of Votes and Rating is 0.11

# %%
#Create new x and y values based on a random sample (n=1000) from the entire dataset
random_x = final_df['numVotes'].sample(n = 1000, random_state = 1)
random_y = final_df['averageRating'].sample(n = 1000, random_state = 1)

# %%
#plot scatterplot based on the random sample from entire dataset
plt.title("Number of Votes vs Average Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(random_x, random_y, marker = "o", color = "cyan")
plt.show()

# %%
print(f"The correlation coefficient between Number of Votes and Rating is {round(st.pearsonr(random_x,random_y)[0],2)}")
# Out:
# The correlation coefficient between Number of Votes and Rating is 0.09

# %%
#Create new dataframe that removes movies with more than 99 votes
less_100_df = final_df.loc[final_df['numVotes'] < 100]
less_100_df.head()
# Out:
#       tconst                    primaryTitle  startYear  runtimeMinutes  \
# 0  tt0000009                      Miss Jerry       1894              45
# 2  tt0000679  The Fairylogue and Radio-Plays       1908             120
# 3  tt0001184         Don Juan de Serrallonga       1910              58
# 4  tt0001258           The White Slave Trade       1910              45
# 5  tt0001285               The Life of Moses       1909              50
#
#                    genres  averageRating  numVotes
# 0                 Romance            5.3        89
# 2       Adventure,Fantasy            4.8        34
# 3         Adventure,Drama            3.1        11
# 4                   Drama            5.7        79
# 5  Biography,Drama,Family            5.1        30

# %%
#set x and y values based on random sample (n=1000) from movies with less than 100 votes
less_100_x = less_100_df['numVotes'].sample(n = 1000, random_state = 1)
less_100_y = less_100_df['averageRating'].sample(n = 1000, random_state = 1)

# %%
#plot scatterplot based on random sample from movies with under 100 votes
plt.title("Number of Votes vs Average Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(less_100_x, less_100_y, marker = "o", color = "purple")
plt.show()

# %%
print(f"The correlation coefficient between Number of Votes and Rating is {round(st.pearsonr(less_100_x, less_100_y)[0],2)}")
# Out:
# The correlation coefficient between Number of Votes and Rating is -0.03

# %%
#Create new dataframe that only contains movies that came out after 1970 
post_1970_df = final_df.loc[final_df["startYear"] >= 1970]
post_1970_df
# Out:
#            tconst                             primaryTitle  startYear  \
# 7665    tt0031458                El hu??sped del sevillano       1970
# 9811    tt0035423                           Kate & Leopold       2001
# 10463   tt0036606              Another Time, Another Place       1983
# 12060   tt0039442                            Habla, mudita       1973
# 20727   tt0054724                          I Eat Your Skin       1971
# ...           ...                                      ...        ...
# 100248  tt0953478                      Lilla sp??ket Laban       2006
# 100249  tt0953483  Made in GDR - Alles ?ªber meine Freunde       2007
# 100250  tt0953564                       A Footstep on Sand       1988
# 100251  tt0953605                                   Sukran       2005
# 100252  tt0953659                     A Suitcaseful of Sex       1971
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 7665                86                  Comedy            7.1         8
# 9811               118  Comedy,Fantasy,Romance            6.4     76547
# 10463              118               Drama,War            6.5       246
# 12060               88                   Drama            6.2       125
# 20727               92                  Horror            3.5      1185
# ...                ...                     ...            ...       ...
# 100248              45        Animation,Family            6.3        63
# 100249              93             Documentary            7.4         5
# 100250             101  Drama,History,Thriller            6.6        11
# 100251             165            Action,Drama            3.2       442
# 100252              93                  Comedy            5.4        22
#
# [64137 rows x 7 columns]

# %%
#set x and y values based on movies after 1970
post_1970_x = post_1970_df['numVotes']
post_1970_y = post_1970_df['averageRating']

# %%
#plot scatterplot based on movies after 1970
plt.title("Number of Votes vs Average Rating (1970 and after)")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(post_1970_x, post_1970_y, marker = "o", color = "blue")
plt.show()

# %%
print(f"The correlation coefficient between Number of Votes and Rating is {round(st.pearsonr(post_1970_x, post_1970_y)[0],2)}")
# Out:
# The correlation coefficient between Number of Votes and Rating is 0.12

# %%
#Create new dataframe that only contains movies that came out after 1970 and recieved less than 100 votes
h_1970_df = post_1970_df.loc[post_1970_df['numVotes'] < 100]
h_1970_df
# Out:
#            tconst                             primaryTitle  startYear  \
# 7665    tt0031458                El hu??sped del sevillano       1970
# 23779   tt0059900          Wenn du gro?? bist, lieber Adam       1990
# 23883   tt0060144              Aventura en las islas C??es       1972
# 24043   tt0060462             The Girls from Thunder Strip       1970
# 24311   tt0060939               Santo vs. the Head Hunters       1971
# ...           ...                                      ...        ...
# 100247  tt0953415                              Go-Go Motel       2003
# 100248  tt0953478                      Lilla sp??ket Laban       2006
# 100249  tt0953483  Made in GDR - Alles ?ªber meine Freunde       2007
# 100250  tt0953564                       A Footstep on Sand       1988
# 100252  tt0953659                     A Suitcaseful of Sex       1971
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 7665                86                  Comedy            7.1         8
# 23779               78           Drama,Fantasy            6.9        23
# 23883               82               Adventure            6.1        16
# 24043               80            Action,Drama            4.4        88
# 24311               80  Action,Adventure,Drama            5.1        31
# ...                ...                     ...            ...       ...
# 100247              73                Thriller            7.1        11
# 100248              45        Animation,Family            6.3        63
# 100249              93             Documentary            7.4         5
# 100250             101  Drama,History,Thriller            6.6        11
# 100252              93                  Comedy            5.4        22
#
# [31683 rows x 7 columns]

# %%
#Set x and y values based on a random sample (n=1000) of movies that came out after 1970
s_1970_x = h_1970_df["numVotes"].sample(n = 1000, random_state = 1)
s_1970_y = h_1970_df["averageRating"].sample(n = 1000, random_state = 1)

# %%
#plot scatterplot based on movies after 1970
plt.title("Number of Votes vs Average Rating (1970 and after)")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(s_1970_x, s_1970_y, marker = "o", color = "pink")
plt.show()

# %%
print(f"The correlation coefficient between Number of Votes and Rating is {round(st.pearsonr(s_1970_x, s_1970_y)[0],2)}")
# Out:
# The correlation coefficient between Number of Votes and Rating is -0.01

# %%
new_df = final_df.loc[final_df["numVotes"] > 50000]
new_df
# Out:
#            tconst                 primaryTitle  startYear  runtimeMinutes  \
# 513     tt0010323  The Cabinet of Dr. Caligari       1920              76
# 735     tt0012349                      The Kid       1921              68
# 883     tt0013442                    Nosferatu       1922              94
# 1236    tt0015648          Battleship Potemkin       1925              75
# 1277    tt0015864                The Gold Rush       1925              95
# ...           ...                          ...        ...             ...
# 100083  tt0942385               Tropic Thunder       2008             107
# 100116  tt0944835                         Salt       2010             100
# 100160  tt0947798                   Black Swan       2010             108
# 100162  tt0947810                   Green Zone       2010             115
# 100187  tt0949731                The Happening       2008              91
#
#                          genres  averageRating  numVotes
# 513      Fantasy,Horror,Mystery            8.1     53531
# 735         Comedy,Drama,Family            8.3    104851
# 883              Fantasy,Horror            7.9     84570
# 1236     Drama,History,Thriller            8.0     50354
# 1277     Adventure,Comedy,Drama            8.2     94133
# ...                         ...            ...       ...
# 100083        Action,Comedy,War            7.0    365037
# 100116  Action,Mystery,Thriller            6.4    285909
# 100160           Drama,Thriller            8.0    673503
# 100162    Action,Drama,Thriller            6.8    125734
# 100187     Drama,Mystery,Sci-Fi            5.0    190715
#
# [1630 rows x 7 columns]

# %%
new_x = new_df["numVotes"]
new_y = new_df["averageRating"]

plt.title("Number of Votes vs Average Rating")
plt.xlabel("Number of Votes")
plt.ylabel("Rating")
plt.scatter(new_x, new_y, marker = "o", color = "pink")
plt.show()

# %% [markdown]
# #### Conclusion: Every correlation coefficient calculated indicates that there is no correlation between the number of votes and movie recieves and the rating of the movie.

# %%
bins = [1970,1980,1990,2000,2010]
year_groups = ["1970-1980","1980-1990","1990-2000","2000-2010"]
final_df["Year group"] = pd.cut(final_df["startYear"], bins, labels = year_groups)
