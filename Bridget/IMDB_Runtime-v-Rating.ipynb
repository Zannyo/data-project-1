# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
final_df = "Resources/final_df.csv"
final_df = pd.read_csv(final_df)
final_df.head()
# Out:
#    Unnamed: 0     tconst                    primaryTitle  startYear  \
# 0           9  tt0000009                      Miss Jerry       1894
# 1         412  tt0000574     The Story of the Kelly Gang       1906
# 2         481  tt0000679  The Fairylogue and Radio-Plays       1908
# 3         781  tt0001184         Don Juan de Serrallonga       1910
# 4         813  tt0001258           The White Slave Trade       1910
#
#    runtimeMinutes                 genres  averageRating  numVotes
# 0              45                Romance            5.3        89
# 1              70  Biography,Crime,Drama            6.1       562
# 2             120      Adventure,Fantasy            4.8        34
# 3              58        Adventure,Drama            3.1        11
# 4              45                  Drama            5.7        79

# %%
x_values = final_df["runtimeMinutes"]
y_values = final_df["averageRating"]

plt.title("Run Time (Minutes) versus Rating - All Datapoints")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
final_df["runtimeMinutes"].describe()
# Out:
# count    100255.000000
# mean         94.292404
# std          30.147896
# min           2.000000
# 25%          83.000000
# 50%          92.000000
# 75%         102.000000
# max        5220.000000
# Name: runtimeMinutes, dtype: float64

# %%
under1000_df = final_df.loc[final_df["runtimeMinutes"]<1000]
under1000_df
# Out:
#         Unnamed: 0     tconst                    primaryTitle  startYear  \
# 0                9  tt0000009                      Miss Jerry       1894
# 1              412  tt0000574     The Story of the Kelly Gang       1906
# 2              481  tt0000679  The Fairylogue and Radio-Plays       1908
# 3              781  tt0001184         Don Juan de Serrallonga       1910
# 4              813  tt0001258           The White Slave Trade       1910
# ...            ...        ...                             ...        ...
# 100250      474785  tt0953564              A Footstep on Sand       1988
# 100251      474790  tt0953605                          Sukran       2005
# 100252      474798  tt0953659            A Suitcaseful of Sex       1971
# 100253      474868  tt0953903                       Year 1863       1922
# 100254      474869  tt0953904                  Romeo i Julcia       1933
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 0                   45                 Romance            5.3        89
# 1                   70   Biography,Crime,Drama            6.1       562
# 2                  120       Adventure,Fantasy            4.8        34
# 3                   58         Adventure,Drama            3.1        11
# 4                   45                   Drama            5.7        79
# ...                ...                     ...            ...       ...
# 100250             101  Drama,History,Thriller            6.6        11
# 100251             165            Action,Drama            3.2       442
# 100252              93                  Comedy            5.4        22
# 100253              93   Drama,History,Romance            6.4        15
# 100254              71                  Comedy            6.1        11
#
# [100252 rows x 8 columns]

# %%
under1000_df["runtimeMinutes"].describe()
# Out:
# count    100252.000000
# mean         94.213951
# std          24.685863
# min           2.000000
# 25%          83.000000
# 50%          92.000000
# 75%         102.000000
# max         763.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = under1000_df["runtimeMinutes"]
y_values = under1000_df["averageRating"]

plt.title("Run Time (Minutes) versus Rating - Movies Under 1000 Minutes")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
under500_df = final_df.loc[final_df["runtimeMinutes"]<500]
under500_df
# Out:
#         Unnamed: 0     tconst                    primaryTitle  startYear  \
# 0                9  tt0000009                      Miss Jerry       1894
# 1              412  tt0000574     The Story of the Kelly Gang       1906
# 2              481  tt0000679  The Fairylogue and Radio-Plays       1908
# 3              781  tt0001184         Don Juan de Serrallonga       1910
# 4              813  tt0001258           The White Slave Trade       1910
# ...            ...        ...                             ...        ...
# 100250      474785  tt0953564              A Footstep on Sand       1988
# 100251      474790  tt0953605                          Sukran       2005
# 100252      474798  tt0953659            A Suitcaseful of Sex       1971
# 100253      474868  tt0953903                       Year 1863       1922
# 100254      474869  tt0953904                  Romeo i Julcia       1933
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 0                   45                 Romance            5.3        89
# 1                   70   Biography,Crime,Drama            6.1       562
# 2                  120       Adventure,Fantasy            4.8        34
# 3                   58         Adventure,Drama            3.1        11
# 4                   45                   Drama            5.7        79
# ...                ...                     ...            ...       ...
# 100250             101  Drama,History,Thriller            6.6        11
# 100251             165            Action,Drama            3.2       442
# 100252              93                  Comedy            5.4        22
# 100253              93   Drama,History,Romance            6.4        15
# 100254              71                  Comedy            6.1        11
#
# [100244 rows x 8 columns]

# %%
under500_df["runtimeMinutes"].describe()
# Out:
# count    100244.000000
# mean         94.170713
# std          24.196600
# min           2.000000
# 25%          83.000000
# 50%          92.000000
# 75%         102.000000
# max         485.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = under500_df["runtimeMinutes"]
y_values = under500_df["averageRating"]

plt.title("Run Time (Minutes) versus Rating - Movies under 500 Minutes")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
after1970_df = under500_df.loc[under500_df["startYear"]>=1970]
after1970_df
# Out:
#         Unnamed: 0     tconst                             primaryTitle  \
# 7665         15867  tt0031458                El hu??sped del sevillano
# 9811         19543  tt0035423                           Kate & Leopold
# 10463        20650  tt0036606              Another Time, Another Place
# 12060        23244  tt0039442                            Habla, mudita
# 20727        37589  tt0054724                          I Eat Your Skin
# ...            ...        ...                                      ...
# 100248      474772  tt0953478                      Lilla sp??ket Laban
# 100249      474773  tt0953483  Made in GDR - Alles ?ªber meine Freunde
# 100250      474785  tt0953564                       A Footstep on Sand
# 100251      474790  tt0953605                                   Sukran
# 100252      474798  tt0953659                     A Suitcaseful of Sex
#
#         startYear  runtimeMinutes                  genres  averageRating  \
# 7665         1970              86                  Comedy            7.1
# 9811         2001             118  Comedy,Fantasy,Romance            6.4
# 10463        1983             118               Drama,War            6.5
# 12060        1973              88                   Drama            6.2
# 20727        1971              92                  Horror            3.5
# ...           ...             ...                     ...            ...
# 100248       2006              45        Animation,Family            6.3
# 100249       2007              93             Documentary            7.4
# 100250       1988             101  Drama,History,Thriller            6.6
# 100251       2005             165            Action,Drama            3.2
# 100252       1971              93                  Comedy            5.4
#
#         numVotes
# 7665           8
# 9811       76547
# 10463        246
# 12060        125
# 20727       1185
# ...          ...
# 100248        63
# 100249         5
# 100250        11
# 100251       442
# 100252        22
#
# [64128 rows x 8 columns]

# %%
after1970_df["runtimeMinutes"].describe()
# Out:
# count    64128.000000
# mean        97.161911
# std         22.495409
# min          2.000000
# 25%         86.000000
# 50%         94.000000
# 75%        105.000000
# max        450.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = after1970_df["runtimeMinutes"]
y_values = after1970_df["averageRating"]

plt.title("Run Time (Minutes) under 500 versus Rating - 1970 to 2010")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
under100_df = after1970_df.loc[after1970_df["runtimeMinutes"]<=100]
under100_df
# Out:
#         Unnamed: 0     tconst                             primaryTitle  \
# 7665         15867  tt0031458                El hu??sped del sevillano
# 12060        23244  tt0039442                            Habla, mudita
# 20727        37589  tt0054724                          I Eat Your Skin
# 23235        41843  tt0058950             Auliban, the Seller of Rings
# 23667        42566  tt0059680                          Satan's Harvest
# ...            ...        ...                                      ...
# 100245      474733  tt0953382                     Trouble at Timpetill
# 100247      474739  tt0953415                              Go-Go Motel
# 100248      474772  tt0953478                      Lilla sp??ket Laban
# 100249      474773  tt0953483  Made in GDR - Alles ?ªber meine Freunde
# 100252      474798  tt0953659                     A Suitcaseful of Sex
#
#         startYear  runtimeMinutes                    genres  averageRating  \
# 7665         1970              86                    Comedy            7.1
# 12060        1973              88                     Drama            6.2
# 20727        1971              92                    Horror            3.5
# 23235        1973              95            Comedy,Musical            7.0
# 23667        1970              88                    Action            3.9
# ...           ...             ...                       ...            ...
# 100245       2008              95  Adventure,Family,Fantasy            5.8
# 100247       2003              73                  Thriller            7.1
# 100248       2006              45          Animation,Family            6.3
# 100249       2007              93               Documentary            7.4
# 100252       1971              93                    Comedy            5.4
#
#         numVotes
# 7665           8
# 12060        125
# 20727       1185
# 23235        121
# 23667        102
# ...          ...
# 100245       838
# 100247        11
# 100248        63
# 100249         5
# 100252        22
#
# [44130 rows x 8 columns]

# %%
under100_df["runtimeMinutes"].describe()
# Out:
# count    44130.000000
# mean        86.537571
# std         11.469035
# min          2.000000
# 25%         83.000000
# 50%         90.000000
# 75%         94.000000
# max        100.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = under100_df["runtimeMinutes"]
y_values = under100_df["averageRating"]

plt.title("Run Time (Minutes) under 100 versus Rating - 1970 to 2010")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
drama_df = under100_df.loc[under100_df["genres"]=="Drama"]
drama_df
# Out:
#         Unnamed: 0     tconst  \
# 12060        23244  tt0039442
# 24977        44932  tt0062181
# 25067        45096  tt0062359
# 25329        45576  tt0062847
# 25416        45709  tt0062980
# ...            ...        ...
# 100199      473828  tt0949875
# 100206      473953  tt0950683
# 100207      473960  tt0950695
# 100228      474232  tt0951338
# 100238      474712  tt0953290
#
#                                              primaryTitle  startYear  \
# 12060                                       Habla, mudita       1973
# 24977                                       Rece do g??ry       1981
# 25067                                     The Bull Buster       1973
# 25329                                      Daddy, Darling       1970
# 25416                             Fleshpot on 42nd Street       1973
# ...                                                   ...        ...
# 100199                                     The New Twenty       2008
# 100206                                       Beat the Air       2006
# 100207  Heisses Blut oder Vivienne del Vargos' letzter...       2005
# 100228                          The Summoning of Everyman       2007
# 100238                              A Ripple in the World       2007
#
#         runtimeMinutes genres  averageRating  numVotes
# 12060               88  Drama            6.2       125
# 24977               76  Drama            6.6       283
# 25067               90  Drama            7.0        21
# 25329               83  Drama            4.9       278
# 25416               87  Drama            6.0       191
# ...                ...    ...            ...       ...
# 100199              92  Drama            5.1       458
# 100206              92  Drama            8.2         6
# 100207              60  Drama            6.7        96
# 100228              50  Drama            8.8         5
# 100238              82  Drama            7.6         7
#
# [7931 rows x 8 columns]

# %%
drama_df["runtimeMinutes"].describe()
# Out:
# count    7931.000000
# mean       87.448493
# std        10.511746
# min         8.000000
# 25%        83.000000
# 50%        90.000000
# 75%        95.000000
# max       100.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = drama_df["runtimeMinutes"]
y_values = drama_df["averageRating"]

plt.title("Run Time (Minutes) under 100 versus Rating - 1970 to 2010 - DRAMAS")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
comedy_df = under100_df.loc[under100_df["genres"]=="Comedy"]
comedy_df
# Out:
#         Unnamed: 0     tconst                              primaryTitle  \
# 7665         15867  tt0031458                 El hu??sped del sevillano
# 25806        46383  tt0063666                              Love, Emilia
# 25849        46459  tt0063751                                  The Howl
# 25929        46687  tt0063982  El abominable hombre de la Costa del Sol
# 25954        46725  tt0064021                  Love Is Gay, Love Is Sad
# ...            ...        ...                                       ...
# 100152      472869  tt0947006                             Evo, vdej se!
# 100218      474169  tt0951224       Polisz kicz projekt... kontratakuje
# 100223      474199  tt0951288                     When a Man Comes Home
# 100230      474250  tt0951368                         All About My Bush
# 100252      474798  tt0953659                      A Suitcaseful of Sex
#
#         startYear  runtimeMinutes  genres  averageRating  numVotes
# 7665         1970              86  Comedy            7.1         8
# 25806        1970              74  Comedy            6.9        53
# 25849        1970              93  Comedy            5.5       322
# 25929        1970              86  Comedy            4.2        28
# 25954        1971              95  Comedy            5.9       112
# ...           ...             ...     ...            ...       ...
# 100152       1984              78  Comedy            5.1        13
# 100218       2006              85  Comedy            3.7        27
# 100223       2007             100  Comedy            5.5       756
# 100230       2007              97  Comedy            3.4       680
# 100252       1971              93  Comedy            5.4        22
#
# [5407 rows x 8 columns]

# %%
comedy_df["runtimeMinutes"].describe()
# Out:
# count    5407.000000
# mean       88.412058
# std         8.497306
# min        22.000000
# 25%        85.000000
# 50%        90.000000
# 75%        94.000000
# max       100.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = comedy_df["runtimeMinutes"]
y_values = comedy_df["averageRating"]

plt.title("Run Time (Minutes) under 100 versus Rating - 1970 to 2010 - COMEDY")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()

# %%
documentary_df = under100_df.loc[under100_df["genres"]=="Documentary"]
documentary_df
# Out:
#         Unnamed: 0     tconst                               primaryTitle  \
# 25734        46255  tt0063550                  Satanis: The Devil's Mass
# 26369        47413  tt0064706                    My Girlfriend's Wedding
# 26675        47922  tt0065227                     Sex Freedom in Germany
# 26735        48100  tt0065411                      Apa ca un bivol negru
# 26755        48140  tt0065453             Cuba: Battle of the 10,000,000
# ...            ...        ...                                        ...
# 100232      474257  tt0951379                                    Rejoice
# 100233      474569  tt0952642             Bhopal: The Search for Justice
# 100240      474717  tt0953303  American Fugitive: The Truth About Hassan
# 100243      474729  tt0953363                     Dalai Lama Renaissance
# 100249      474773  tt0953483    Made in GDR - Alles ?ªber meine Freunde
#
#         startYear  runtimeMinutes       genres  averageRating  numVotes
# 25734        1970              86  Documentary            5.8       396
# 26369        1973              60  Documentary            6.4        60
# 26675        1970              83  Documentary            4.6        13
# 26735        1970              62  Documentary            8.5        25
# 26755        1971              58  Documentary            8.1        17
# ...           ...             ...          ...            ...       ...
# 100232       2004              48  Documentary            8.0         7
# 100233       2004              52  Documentary            8.1        15
# 100240       2006              75  Documentary            7.2        15
# 100243       2007              81  Documentary            6.8        52
# 100249       2007              93  Documentary            7.4         5
#
# [4178 rows x 8 columns]

# %%
documentary_df["runtimeMinutes"].describe()
# Out:
# count    4178.000000
# mean       72.868597
# std        16.190428
# min         2.000000
# 25%        58.000000
# 50%        75.000000
# 75%        87.000000
# max       100.000000
# Name: runtimeMinutes, dtype: float64

# %%
x_values = documentary_df["runtimeMinutes"]
y_values = documentary_df["averageRating"]

plt.title("Run Time (Minutes) under 100 versus Rating - 1970 to 2010 - DOCUMENTARY")
plt.xlabel("Run Time (Minutes)")
plt.ylabel("Average Rating")
plt.scatter(x_values, y_values)
plt.show()
